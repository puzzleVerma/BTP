# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('0hp_all_faults.csv')

# %% [markdown]
# # Segmenting the Vibration signal into small portions using a window

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len=1000
stride=200

X=[]
Y=[]


for k in df['fault'].unique():
    
    df_temp_2 = df[df['fault']==k]
    
    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])
    
X=np.array(X)
X=X.reshape((X.shape[0],win_len))



Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
X.shape
# Out:
# (13848, 1000)

# %% [markdown]
# # Splitting the data into Train and Test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %% [markdown]
# # Visulaizing the data using t-sne before using Auto-Encoders

# %%
X_pre_aen = X

from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(X_pre_aen)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['t-SNE component 1', 't-SNE component 2'])

tSNEdf['Fault']=Y


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(x=tSNEdf['t-SNE component 1'],y=tSNEdf['t-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# C:\Users\prajj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 13848 samples in 0.016s...
# [t-SNE] Computed neighbors for 13848 samples in 4.312s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13848
# [t-SNE] Computed conditional probabilities for sample 2000 / 13848
# [t-SNE] Computed conditional probabilities for sample 3000 / 13848
# [t-SNE] Computed conditional probabilities for sample 4000 / 13848
# [t-SNE] Computed conditional probabilities for sample 5000 / 13848
# [t-SNE] Computed conditional probabilities for sample 6000 / 13848
# [t-SNE] Computed conditional probabilities for sample 7000 / 13848
# [t-SNE] Computed conditional probabilities for sample 8000 / 13848
# [t-SNE] Computed conditional probabilities for sample 9000 / 13848
# [t-SNE] Computed conditional probabilities for sample 10000 / 13848
# [t-SNE] Computed conditional probabilities for sample 11000 / 13848
# [t-SNE] Computed conditional probabilities for sample 12000 / 13848
# [t-SNE] Computed conditional probabilities for sample 13000 / 13848
# [t-SNE] Computed conditional probabilities for sample 13848 / 13848
# [t-SNE] Mean sigma: 1.404057
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 93.106110
# [t-SNE] KL divergence after 300 iterations: 4.162902

# %%
tSNEdf
# Out:
#        t-SNE component 1  t-SNE component 2  Fault
# 0               1.113113          -1.899920  14_BA
# 1               1.600441          -1.980379  14_BA
# 2               1.404561          -2.217367  14_BA
# 3               2.282344          -0.747680  14_BA
# 4               2.186932          -0.461917  14_BA
# ...                  ...                ...    ...
# 13843           2.818441          -3.423583      N
# 13844           2.542534          -4.377428      N
# 13845           3.801288          -2.897932      N
# 13846           4.098597          -4.432142      N
# 13847           2.536017          -3.521566      N
#
# [13848 rows x 3 columns]

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten


# from tensorflow.keras.models import load_model
# AE_model = load_model(r'Trained Model\AE_model_gear.h5')


no_classes=len(encoder.classes_)
# build a model
model = Sequential()
model.add(Dense(1024, input_shape=(X.shape[1],), activation='relu')) # input shape is (features,)
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))
model.summary()

# compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', # this is different instead of binary_crossentropy (for regular classification)
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              1025024
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 14)                1806
#
# =================================================================
# Total params: 1,715,854
# Trainable params: 1,715,854
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=50, # you can set this to a big number!
                    batch_size=500,
                    shuffle=True,
                    validation_data=(X_test,y_test),
                    verbose=1)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 1s 32ms/step - loss: 1.6856 - accuracy: 0.4002 - val_loss: 1.1753 - val_accuracy: 0.5815
# Epoch 2/50
# 20/20 [==============================] - 1s 26ms/step - loss: 0.8204 - accuracy: 0.7559 - val_loss: 0.6361 - val_accuracy: 0.8178
# Epoch 3/50
# 20/20 [==============================] - 1s 28ms/step - loss: 0.3868 - accuracy: 0.8860 - val_loss: 0.3261 - val_accuracy: 0.8958
# Epoch 4/50
# 20/20 [==============================] - 1s 28ms/step - loss: 0.1858 - accuracy: 0.9449 - val_loss: 0.2342 - val_accuracy: 0.9102
# Epoch 5/50
# 20/20 [==============================] - 1s 27ms/step - loss: 0.1160 - accuracy: 0.9645 - val_loss: 0.2140 - val_accuracy: 0.9319
# Epoch 6/50
# 20/20 [==============================] - 1s 27ms/step - loss: 0.3183 - accuracy: 0.9390 - val_loss: 0.3099 - val_accuracy: 0.8977
# Epoch 7/50
# 20/20 [==============================] - 1s 28ms/step - loss: 0.1273 - accuracy: 0.9657 - val_loss: 0.1687 - val_accuracy: 0.9432
# Epoch 8/50
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0489 - accuracy: 0.9907 - val_loss: 0.1451 - val_accuracy: 0.9540
# Epoch 9/50
# 20/20 [==============================] - 1s 27ms/step - loss: 0.0325 - accuracy: 0.9944 - val_loss: 0.1723 - val_accuracy: 0.9478
# Epoch 10/50
# 20/20 [==============================] - 1s 26ms/step - loss: 0.0339 - accuracy: 0.9953 - val_loss: 0.1631 - val_accuracy: 0.9540
# Epoch 11/50
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0319 - accuracy: 0.9927 - val_loss: 0.2105 - val_accuracy: 0.9451
# Epoch 12/50
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0565 - accuracy: 0.9854 - val_loss: 0.2264 - val_accuracy: 0.9369
# Epoch 13/50
# 20/20 [==============================] - 1s 26ms/step - loss: 0.0533 - accuracy: 0.9842 - val_loss: 0.1811 - val_accuracy: 0.9468
# Epoch 14/50
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0450 - accuracy: 0.9893 - val_loss: 0.1802 - val_accuracy: 0.9446
# Epoch 15/50
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0494 - accuracy: 0.9887 - val_loss: 0.1560 - val_accuracy: 0.9540
# Epoch 16/50
# 20/20 [==============================] - 0s 25ms/step - loss: 0.0405 - accuracy: 0.9902 - val_loss: 0.2191 - val_accuracy: 0.9437
# Epoch 17/50
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0396 - accuracy: 0.9922 - val_loss: 0.1778 - val_accuracy: 0.9531
# Epoch 18/50
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0315 - accuracy: 0.9941 - val_loss: 0.1552 - val_accuracy: 0.9600
# Epoch 19/50
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0400 - accuracy: 0.9915 - val_loss: 0.1605 - val_accuracy: 0.9562
# Epoch 20/50
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0241 - accuracy: 0.9945 - val_loss: 0.1159 - val_accuracy: 0.9665
# Epoch 21/50
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0360 - accuracy: 0.9923 - val_loss: 0.1484 - val_accuracy: 0.9593
# Epoch 22/50
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0212 - accuracy: 0.9949 - val_loss: 0.1546 - val_accuracy: 0.9644
# Epoch 23/50
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0074 - accuracy: 0.9991 - val_loss: 0.1479 - val_accuracy: 0.9644
# Epoch 24/50
# 20/20 [==============================] - 1s 26ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.0859 - val_accuracy: 0.9752
# Epoch 25/50
# 20/20 [==============================] - 1s 25ms/step - loss: 0.0036 - accuracy: 0.9998 - val_loss: 0.0947 - val_accuracy: 0.9735
# Epoch 26/50
# 20/20 [==============================] - 1s 28ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9750
# Epoch 27/50
# 20/20 [==============================] - 1s 25ms/step - loss: 6.9803e-04 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 0.9742
# Epoch 28/50
# 20/20 [==============================] - 1s 26ms/step - loss: 5.6104e-04 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9757
# Epoch 29/50
# 20/20 [==============================] - 1s 28ms/step - loss: 4.9761e-04 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9752
# Epoch 30/50
# 20/20 [==============================] - 1s 26ms/step - loss: 4.4602e-04 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9757
# Epoch 31/50
# 20/20 [==============================] - 1s 26ms/step - loss: 4.0624e-04 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9750
# Epoch 32/50
# 20/20 [==============================] - 1s 26ms/step - loss: 3.7199e-04 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9757
# Epoch 33/50
# 20/20 [==============================] - 1s 26ms/step - loss: 3.4652e-04 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9757
# Epoch 34/50
# 20/20 [==============================] - 1s 25ms/step - loss: 3.2266e-04 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9759
# Epoch 35/50
# 20/20 [==============================] - 0s 25ms/step - loss: 3.0166e-04 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9755
# Epoch 36/50
# 20/20 [==============================] - 1s 26ms/step - loss: 2.8369e-04 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9755
# Epoch 37/50
# 20/20 [==============================] - 1s 26ms/step - loss: 2.6522e-04 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9762
# Epoch 38/50
# 20/20 [==============================] - 0s 24ms/step - loss: 2.4979e-04 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9757
# Epoch 39/50
# 20/20 [==============================] - 0s 25ms/step - loss: 2.3643e-04 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9757
# Epoch 40/50
# 20/20 [==============================] - 1s 26ms/step - loss: 2.2318e-04 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9759
# Epoch 41/50
# 20/20 [==============================] - 0s 25ms/step - loss: 2.1223e-04 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9759
# Epoch 42/50
# 20/20 [==============================] - 0s 25ms/step - loss: 2.0182e-04 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9757
# Epoch 43/50
# 20/20 [==============================] - 0s 25ms/step - loss: 1.9181e-04 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9757
# Epoch 44/50
# 20/20 [==============================] - 0s 24ms/step - loss: 1.8323e-04 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9759
# Epoch 45/50
# 20/20 [==============================] - 0s 24ms/step - loss: 1.7488e-04 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 0.9759
# Epoch 46/50
# 20/20 [==============================] - 1s 26ms/step - loss: 1.6737e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9757
# Epoch 47/50
# 20/20 [==============================] - 1s 26ms/step - loss: 1.6006e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9755
# Epoch 48/50
# 20/20 [==============================] - 0s 24ms/step - loss: 1.5354e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9759
# Epoch 49/50
# 20/20 [==============================] - 0s 25ms/step - loss: 1.4695e-04 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 0.9757
# Epoch 50/50
# 20/20 [==============================] - 0s 24ms/step - loss: 1.4134e-04 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9757

# %%
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['accuray','val_accuracy'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
plt.show()

# %%
dummy_ann = Model(inputs=model.input,outputs=model.layers[-2].output)
y_viz = dummy_ann.predict(X_train)

# %%
y_viz.shape
# Out:
# (9693, 128)

# %%
def T_SNE_plot(X_train,y_train,model,encoder):
    
    dummy_ann = Model(inputs=model.input,outputs=model.layers[-2].output)
    y_viz = dummy_ann.predict(X_train)
    
    from sklearn.manifold import TSNE

    X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

    tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

    tSNEdf['Fault']=inv_Transform_result(y_train)


    # Plot the PC-1 and PC-2
    fig, ax = plt.subplots(figsize=(10,10))
    sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
        data=tSNEdf,
        legend="full",
        alpha=0.3)
    plt.show()

# %%
T_SNE_plot(X_train,y_train,model,encoder)
# Out:
# C:\Users\prajj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9693 samples in 0.000s...
# [t-SNE] Computed neighbors for 9693 samples in 1.810s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9693
# [t-SNE] Computed conditional probabilities for sample 2000 / 9693
# [t-SNE] Computed conditional probabilities for sample 3000 / 9693
# [t-SNE] Computed conditional probabilities for sample 4000 / 9693
# [t-SNE] Computed conditional probabilities for sample 5000 / 9693
# [t-SNE] Computed conditional probabilities for sample 6000 / 9693
# [t-SNE] Computed conditional probabilities for sample 7000 / 9693
# [t-SNE] Computed conditional probabilities for sample 8000 / 9693
# [t-SNE] Computed conditional probabilities for sample 9000 / 9693
# [t-SNE] Computed conditional probabilities for sample 9693 / 9693
# [t-SNE] Mean sigma: 2.600212
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.373550
# [t-SNE] KL divergence after 300 iterations: 2.128376

# %%
def Test_model_diff_loading(load,win_len,stride,model):
    
    df = pd.read_csv('{}hp_all_faults.csv'.format(load))

#     win_len=1000
#     stride=200

    X=[]
    Y=[]


    for k in df['fault'].unique():

        df_temp_2 = df[df['fault']==k]

        for i in np.arange(0,len(df_temp_2)-(win_len),stride):
            temp = df_temp_2.iloc[i:i+win_len,:-1].values
            temp = temp.reshape((1,-1))
            X.append(temp)
            Y.append(df_temp_2.iloc[i+win_len,-1])

    X=np.array(X)
    X=X.reshape((X.shape[0],win_len))



    Y=np.array(Y)
    encoder2= LabelEncoder()
    encoder2.fit(Y)
    encoded_Y = encoder2.transform(Y)
    OHE_Y = to_categorical(encoded_Y)


    def inv_Transform_result(y_pred,encoder):    
        y_pred = y_pred.argmax(axis=1)
        y_pred = encoder.inverse_transform(y_pred)
        return y_pred



    y_pred=model.predict(X)
    
    print('Accuracy on Load-{}hp data is---{}%'.format(load,(model.evaluate(X,OHE_Y)[1])*100))


    Y_pred=inv_Transform_result(y_pred,encoder2)
    Y_test = Y

    from sklearn.metrics import confusion_matrix


    plt.figure(figsize=(10,10))
    cm = confusion_matrix(Y_test, Y_pred,normalize='true')
    f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
    plt.show()
    print()
    
    T_SNE_plot(X[::10,:],OHE_Y[::10,:],model,encoder2)

# %%
# Test_model_diff_loading(load=1,win_len=1000,stride=200,model=model)

# %%
# Test_model_diff_loading(load=2,win_len=1000,stride=200,model=model)

# %%
Test_model_diff_loading(load=3,win_len=1000,stride=200,model=model)
# Out:
# 1063/1063 [==============================] - 3s 2ms/step - loss: 18.8449 - accuracy: 0.3080
# Accuracy on Load-3hp data is---30.795013904571533%
# C:\Users\prajj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3402 samples in 0.000s...
# [t-SNE] Computed neighbors for 3402 samples in 0.194s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3402
# [t-SNE] Computed conditional probabilities for sample 2000 / 3402
# [t-SNE] Computed conditional probabilities for sample 3000 / 3402
# [t-SNE] Computed conditional probabilities for sample 3402 / 3402
# [t-SNE] Mean sigma: 3.914992
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.345993
# [t-SNE] KL divergence after 300 iterations: 1.736121
